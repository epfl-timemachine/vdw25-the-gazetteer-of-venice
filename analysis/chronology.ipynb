# %%
import json
import re
import pandas as pd
import roman

# %%
#Import entity recognition
entity_file = "../NER/NER_results.txt"
place_entity_dict = dict()
with open(entity_file, 'r', encoding='utf-8') as ef:
    for line in ef.readlines():
        line = line.strip().lstrip('%').strip()
        split_line = line.split('%')
        place = split_line[0]
        entities = split_line[1].split('#')
        
        if place not in place_entity_dict.keys():
            place_entity_dict[place] = entities

print(place_entity_dict)
# Out:
# {'Abate (Corte dell’)  a S. Gregorio.': ['Descrizione della Contrada di S. Gregorio', 'X Savii', 'Decime', '1661', 'Corte', 'dell’Abate', 'case', 'Abazia di S. Gregorio', '1703', 'cardinale Ottobuoni', 'Pietro Ottobuono', 'Venezia', '1667', '1689', 'Papa Alessandro VIII', 'cardinale', 'ecclesiastico', 'Avignone', 'Santa Chiesa', '1693', 'abazia di S. Gregorio', '1701', 'Antonio', 'Senato', '1710', 'Francia', 'Corte Romana', 'Libro d’Oro', '1740', 'Ottobuoni', 'Emmanuele Cicogna', '«Inscrizioni Veneziane»'], 'Abazia (Calle dell’)  a S. Gregorio.': ['Abate'], 'Abazia (Fondamenta, Sottoportico, Campo, Ponte, Fondamenta dell’)  a S. Maria della Misericordia.': ['chiesa abaziale', 'S. Maria della Misericordia', 'l’Abazia', '939', 'Val Verde', 'Cesare dei Giulii', 'Andreardo', 'Giulia', 'Moro', 'Agostiniani', '1348', 'Luca Moro', '1369', 'secolo XVII', 'Clemente Moli', 'Gasparo Moro', 'Pietro Pianton', '1868', '1884', 'patriarca di Venezia', 'Domenico Agostini', 'Girolamo Savina', 'Clemente VIII', '9 giugno 1601', 'Lovisa', 'Ponte dell’Abazia', 'secolo scorso', '1833', 'Fondamenta dell’Abazia', 'Corte Nuova', 'Scuola Grande di S. Maria della Misericordia', 'ospizio', 'ospedaletto', '1505', 'Leonardo Loredan'], 'Accademia (Calle della)  alla Giudecca.': ['Repubblica', '1619', 'Accademia', 'Collegio', '1627', '46', '20', 'Fabio Mutinelli', '«Lessico Veneto»', 'Giovanni Domenico', 'Brustolon', '«Uomo di Stato»', '«Trattato di Politica»', 'Venezia', '1798', 'Zatta', 'sacerdoti', 'secolari', 'secolo', 'Religiosi Somaschi', 'Stanislao Santinelli'], 'Acqua dolce (Rio dell’)  ai Ss. Apostoli.': ['Dezan', '«Iconografia delle trenta parrocchie di Venezia»', 'Paganuzzi', 'terraferma', 'secolo XIV', '25 dicembre 1386', '«Campo di S. Basegio»', 'campanile', 'casa', 'scuola', 'altare', 'chiesa', 'S. Costanzo', 'S. Gregorio', '«mariegola»', '1741', '1773', '18', '8', '100', '20', 'Venezia', 'Giustizieri Vecchi', 'Provveditori alla Giustizia Vecchia', 'Magistrato della Sanità', 'Collegio Milizia da Mar'], 'Acquavita (Ponte, Calle dell’)  ai Gesuiti.': ['Descrizione della Contrada dei Ss. Apostoli', '1713', 'Senato', '29 agosto 1711', 'Calle dell’Acquavita', 'Gesuiti', 'bottega d’acquavita', 'Elia Giannazzi', 'Monsignor Marco Gradenigo', 'patriarca d’Aquileia', 'acquavitai', 'caffettieri', 'ghiaccio', 'acquavite', 'Venezia', '1773', '1601', 'chiesa', 'S. Stefano', 'S. Stin', 'S. Giovanni Battista'], 'Acque (Sottoportico, Calle delle)  a S. Salvatore.': ['botteghe da caffè', 'botteghe da acque', '«Condizioni»', '1566', 'Alvise Giusto', 'Girolamo Giusto', '«Calle delle Acque»', 'S. Salvatore', 'bottega', 'Isabetta dalle Acque', '1712', 'G. Maria Pizzotti', 'Coronelli'], 'Agnello (Ramo al Ponte, Ponte, Ramo Fondamenta, Fondamenta, Calle dell’)  a S. M. Mater Domini.': ['Dalla Agnella', 'Agnello'], 'Albanesi (Calle degli)  a SS. Filippo e Giacomo.': ['Dezan', 'Albanesi', 'Calle degli Albanesi', 'SS. Filippo e Giacomo', '1851', 'Riva dei Schiavoni', 'prigioni', 'S. Severo', '1443', 'Consiglio dei X', 'contrada di S. Maurizio', 'chiesa', 'Mariegola', 'Marciana', '1497', '1500', '1501', '1502', '1532', 'B. V.', 'S. Gallo', 'S. Maurizio', 'Scutari', 'Albania', 'Turchi', '1474', 'Antonio Loredan', '1479', 'mezza luna ottomana', 'Scuola degli Albanesi', 'Repubblica', 'Pistori', 'Campo S. Maurizio', 'Loco Dello Stendardo della B. V. Dei Albanesi Ora Dei Pistori', 'Pistor (Calle del)'], 'Alberegno (Calle)  ai Servi.': ['Calle dell’Alberegno', '1661', 'Lorenzo Alberegno', 'Fondamenta Ormesini', 'Alberegno', 'Alberengo', 'giesia de S. Salvador de Muran', '1301', '1310', 'Giacomo', 'Ufficio del Proprio', 'Cicogna', 'Michele Alberegno', '1558', 'cronaca Veneziana'], 'Albero (Ramo al Ponte, Ponte, Fondamenta, Calle, Rami Corte, Corte dell’)  a S. Angelo.': ['Corte di cha Marcello', 'Alboro', 'Marcello', 'Teodoro Damaden', '«Genealogie Marcello»', 'Museo Correr', 'S. Angelo', 'Vasari', 'palazzo Corner', 'Spinelli', 'Corte dell’Albero', '1542', 'casa Cornaro', 'S. Ben ...

# %%
def check_if_century(entity, place):
    try:
        century = int(roman.fromRoman(entity))
        if century < 6:
            return None
        if century < 20:
            century = century * 100 + 50
            print(place)
            print(century)
            return century
        if century < 450:
            return None
        print(place)
        print(century)
        return century

    except:
        return None

# %%
def check_if_year(entity, place):
    # 1st we check if the entity is a straight year
    try:
        year = int(entity)
        if year < 1864 and year > 400:
            return year
    except:
        pass

    # Then we check if the entity is a date (with a year)
    pattern = r'([0-9]{3,4})'
    years_found = re.findall(pattern, entity)
    if years_found != []:
        return years_found
    
    #see if there is a century mentionned and transform it into an int
    century = check_if_century(entity, place)
    if century:
        return century

    return None

# %%
# Retain only years for each place
place_year_dict = dict()
for place, entities in place_entity_dict.items():
    year_list = []
    for entity in entities:
        year = check_if_year(entity, place)
        if year and type(year) is int:
            year_list.append(year)
        elif year and type(year) is list:
            year_list + year

    place_year_dict[place] = sorted(year_list)

with open("../out/place_entity_dict.json", "w", encoding='utf-8') as fp:
    json.dump(place_year_dict , fp, ensure_ascii=False)
# Out:
# Albrizzi (Ramo e Campiello, Calle, Campiello)  a S. Apollinare.
# 1650
# Amai (Calle dei)  a S. Giovanni Gr isostomo.
# 1450
# Amai (Calle dei)  a S. Giovanni Gr isostomo.
# 1650
# Angelo Raffaele (Parrocchia, Campo, Rio, Pon te dell’).
# 1862
# Annunziata (Sottoportico, Corte della)  a S. Maria Formosa.
# 1681
# Armeni (Calle, Ramo d egli) a S. Giuliano.
# 1550
# Aséo (Calle e Ponte dell’)  ai SS. Ermagora e Fortunato.
# 1550
# Aséo (Calle e Ponte dell’)  ai SS. Ermagora e Fortunato.
# 1650
# Avogarìa (Ponte, Rio, Ramo, Calle della)  a S. Barnaba.
# 1750
# Badoer (Ramo, Sottoportico, Corte)  ai Frari.
# 1250
# Balastro (Calle, Ramo, Sottoportico, Campiello)  a S. Basilio.
# 1350
# Barbarigo (Corte)  all’Angelo Raffaele.
# 1592
# Barbaro (Corte, Fondamenta, Ramo, Fondamenta, Calle)  a S. Vitale.
# 1450
# Barbo (Ramo Corte, Corte, Ramo Corte seconda)  a S. Pantaleone.
# 1550
# Baretteri (Ponte, Rio dei)  a S. Salvatore.
# 1350
# Baretteri (Ponte, Rio dei)  a S. Salvatore.
# 1450
# Baretteri (Ponte, Rio dei)  a S. Salvatore.
# 1650
# Beccarie (Calle , Campo, Ponte, Rio, Calle delle)  a Rialto.
# 1250
# Beccarie (Calle , Campo, Ponte, Rio, Calle delle)  a Rialto.
# 1450
# Benedetto (Campo, Traghetto).
# 1650
# Bergamaschi (Calle)  a S. Moisè.
# 1650
# Bergamaschi (Calle)  a S. Moisè.
# 1750
# Bianco (Corte del)  a Castello.
# 1650
# Biasio (Riva, Traghetto della Riva di)  a S. Simeon Gran de.
# 1750
# Bolza (Calle della)  a SS. Ermagora e Fortunato.
# 1450
# Borgo (Fondamenta, Ponte di)  ai SS. Gervasio e Protasio.
# 1450
# Borsa (Corte, Ramo e Corte, Calle della)  a S. Ternita.
# 1450
# Bosello (Calle, Campo)  presso la «Fondamenta di San Giobbe».
# 1650
# Bosello (Calle, Campo)  presso la «Fondamenta di San Giobbe».
# 1750
# Brentana (Calle)  a S. Moisè.
# 1650
# Briani (Calle)  all’Angelo Raffaele.
# 950
# Briani (Calle)  all’Angelo Raffaele.
# 1450
# Burchielle (Rio, Fondamenta del Rio delle)  a S. Andrea.
# 650
# Caliari (Calle)  sulla «Fondamenta degli Ormesini».
# 1850
# Canal (Fondamenta, Ramo, Ponte)  a S. Barnaba.
# 1350
# Canal (Fondamenta, Ramo, Ponte)  a S. Barnaba.
# 1750
# Cappellèr (Sottoportico e Calle, Ramo e Calle del)  a S. Cassiano.
# 1550
# Cappellèr (Sottoportico e Calle, Ramo e Calle del)  a S. Cassiano.
# 1750
# Cappello (Sottoportico e Calle del)  a S. Marco.
# 1450
# Carminati (Ramo, Salizz ada, Ramo secondo Salizzada, Ramo terzo Salizzada) a S. Eustachio.
# 1450
# Carminati (Ramo, Salizz ada, Ramo secondo Salizzada, Ramo terzo Salizzada) a S. Eustachio.
# 1550
# Carmine (Campo, Rio del).
# 1350
# Carmine (Campo, Rio del).
# 1750
# Carro (Calle e Ramo, Campiello della Calle, Ramo della Calle del)  a S. Marco, presso la «Frezzeria».
# 1650
# Castel Forte (Ramo, Calle dietro, Sottoportico, Calle di)  a S. Rocco.
# 1550
# Castelli (Calle e Corte)  ai Miracoli.
# 1650
# Castello (Sestiere, Parrocchia di S. Pietro, Canale di).
# 1550
# Cavalletto (Sottoportico, Ponte, Rio, Calle del)  a San Marco.
# 1650
# Celestia (Campo, Rio della)
# 1450
# Celestia (Campo, Rio della)
# 1550
# Celestia (Campo, Rio della)
# 1650
# Cendon (Calle)  a S. Giobbe.
# 1550
# Centani (Calle, Ramo, Campiello)  a S. Tomà.
# 1450
# Cerchieri (Ramo Calle, Calle dei) a S. Barnaba.
# 1550
# Cereri (Fondamenta dei)  a S. Maria Maggi ore.
# 1650
# Cereri (Fondamenta dei)  a S. Maria Maggi ore.
# 1850
# Coco detta del Remer (Calle)  a S. Maria Formosa.
# 1050
# Confraternita (Campo della)  a S. Francesco della Vigna.
# 1750
# Confraternita (Campo della)  a S. Francesco della Vigna.
# 1671
# Contarina (Sottoportico e Corte, Ramo Primo Corte, Ramo Secondo Corte)  a S. Moisè.
# 1450
# Contarini Corfù (Calle)  ai SS. Gervasio e Protasio.
# 1450
# Coppo (Corte del)  o del Forno  a S. Luca.
# 1350
# Corazzeri (Ramo)  a S. Antonino.
# 1450
# Corelie (Rio delle)  a S. Girolamo.
# 1450
# Corner Zaguri (Ponte e Fondamenta)  a S. Maurizio.
# 1450
# Corpus Domini (Campo, Fondamenta  del).
# 1550
# Correr (Ponte e Calle, Calle)  a S. Fosca.
# 950
# Cortese (Calle)  ai SS. Giovanni e Paolo.
# 1550
# Croce (Sestiere, Fondamenta, Rio, Ponte della).
# 1450
# Croce (Sestiere, Fondamenta, Rio, Ponte della).
# 1650
# Da Mula (Ramo)  a S. Vito.
# 1550
# Da Ponte (Calle e Corte)  a S. Maurizio.
# 1650
# Due Pozzi  (Campo dei)  a S. Martino.
# 1450
# Due Pozzi  (Campo dei)  a S. Martino.
# 1750
# Due Pozzi  (Campo dei)  a S. Martino.
# 1850
# Dario (Sottoportico e Corte)  al Gesù e Maria.
# 1550
# Diedo (Fondamenta, Fondamenta e Ponte, Campiello)  a S. Fosca.
# 1450
# Erberia (Sottoportico della)  a Rialto.
# 1350
# Èrizzo (Ramo primo, Calle, Ramo, Corte)  alla Maddalena.
# 1550
# Fontego dei Tedeschi (Calle, Ramo, Salizzada, Rio del)  a S. Bartolomeo.
# 1350
# Fontego dei Turchi (Salizzada del) a S. Giovanni Decollato.
# 1350
# Fruttaròl (Calle del)  a S. Fantino.
# 1250
# Farsetti (Traghetto)  a S. Luca.
# 1350
# Fava (Calle e Rami dietro la, Campo, Ponte, Calle della).
# 1550
# Finetta (Ramo)  a S. Sofia.
# 1450
# Finetta (Ramo)  a S. Sofia.
# 1650
# Franchi (Calle dei)  a S. Vito.
# 1550
# Frezzarìa (Piscina, Ramo di)  a S. Marco.
# 1450
# Gradenigo (Fondamenta)  a S. Simeon Grande.
# 1750
# Gallo (Cort e e Rami, Ramo del)  al «Malcanton».
# 1650
# Gatte (Salizzada, Ramo, Campo delle)  a San Francesco della Vigna.
# 750
# Gatte (Salizzada, Ramo, Campo delle)  a San Francesco della Vigna.
# 1549
# Gàffaro (Ponte, Rio, Fondamenta del)  ai Tolentini.
# 1650
# Gesuiti (Campo, Rio, Ponte dei).
# 1350
# Gesuiti (Campo, Rio, Ponte dei).
# 1550
# Gioachina (Calle, Ramo, Calle)  a S. Geremia.
# 1750
# Giovanelli (Sottoportico)  a S. Eustachio.
# 1650
# Giustinian (Calle)  a S. Barnaba .
# 1250
# Giustinian (Calle)  a S. Barnaba .
# 1550
# Gozzi (Rio d el) ai Gesuiti.
# 1650
# Gozzi (Rio d el) ai Gesuiti.
# 1750
# Gradisca (Calle, Ramo ) a S. Giacomo dall’Orio.
# 1450
# Gradisca (Calle, Ramo ) a S. Giacomo dall’Orio.
# 1550
# Indorador (Sottoportico e Corte, Corte del)  a S. Marina.
# 1550
# Indorador (Sottoportico e Corte, Corte del)  a S. Marina.
# 1650
# Loredan (Campiello)  a S. Stefano.
# 1450
# Loredan (Campiello)  a S. Stefano.
# 1650
# Limante (Corte)  a S. Girolamo.
# 1750
# Lunga (Calle)  a S. Maria Formosa.
# 1350
# Malvasia vecchia (Ponte, Sottoportico, Campiello della)  a S. Fantino.
# 1750
# Malvasia vecchia (Ponte, Sottoportico, Campiello della)  a S. Fantino.
# 1850
# Marcello o Pindemonte (Ponte e Calle)  a S. Marina.
# 1450
# Muazzo (Calle, Ramo Corte, Corte)  in «Barbaria delle Tole».
# 1350
# Muti o Baglioni (Calle)  a S. Cassiano.
# 1850
# Malatina (Sottoportico e Corte)  a S. Maurizio.
# 1450
# Malipiero (Calle, Ramo, Salizzada)  a San Samuele.
# 1750
# Malipiero (Calle, Ramo, Salizzada)  a San Samuele.
# 1650
# Margaritera (Corte) a San Martino.
# 1350
# Mazzorana (Calle)  ai SS. Apostoli.
# 1650
# Menùo (Rio).
# 1250
# Miani (Ramo Corte, Corte)  a S. Cassiano.
# 1550
# Minio (Calle)  a S. Fosca .
# 1650
# Minotto (Fondamenta, Sottoportico)  ai Tolentini.
# 1450
# Morion (Calle, Sottoportico del)  a S. Francesco della Vigna.
# 1450
# Morolin (Ramo, Sottoportico, Calle)  a S. Samuele.
# 1750
# Morosini (Calle, Corte) a S. Giovanni Grisostomo.
# 1050
# Mosche (Cam po, Ramo, Campiello delle)  a S. Pantaleone.
# 1650
# Nani (Calle larga, Fondamenta)  ai SS. Gervasio e Protasio.
# 1450
# Nuovo (Campiello)  a San Stefano.
# 1838
# Nuovo (Campiello)  a San Stefano.
# 1750
# Ognissanti (Fondamenta, Ponte, Rio, Campo, Fondamenta, Ponte degli).
# 1550
# Orbi (Calle degli)  a S. Samuele.
# 1550
# Orso (Sottoportico e Calle, Calle e Corte dell’)  a S. Bartolammeo.
# 1450
# Orto (Corte dell’)  in Ghetto Vecchio.
# 1650
# Ospitaletto  (Calle dell’)  alla Giudecca.
# 1832
# Pietà (Calle, Corte della)  a San Francesco della Vigna.
# 1450
# Pietà (Ponte, Calle, Rio della, Ponte e Calle dietro la)  a San Giovanni in Bragora.
# 1750
# Pietà (Ponte, Calle, Rio della, Ponte e Calle dietro la)  a San Giovanni in Bragora.
# 1850
# Pin (Ramo Calle del)  a S. Cassiano.
# 1450
# Piovàn (Calle, Fondamenta del)  a S. Martino.
# 1250
# Pisani (Campo)  a San Stefano.
# 1650
# Pisani e Barbarigo (Ramo)  a S. Tomà.
# 1550
# Posta (Via alla)  a S. Salvatore.
# 1250
# Posta (Via alla)  a S. Salvatore.
# 1550
# Posta (Calle, Corte della)  ai SS. Apostoli, presso il «Campiello Valmarana».
# 1650
# Padovani (Ramo dei)  ai Santi Filippo e Giacomo, in «Calle delle Rasse».
# 1650
# Paradiso (Ponte, Calle del)  a S. Maria Formosa.
# 1450
# Parrucchetta (Ponte, Fondamenta, Rio Terrà, Ramo del) a S. Giacomo dall’Orio.
# 1550
# Parrucchetta (Ponte, Fondamenta, Rio Terrà, Ramo del) a S. Giacomo dall’Orio.
# 1650
# Paruta (Corte)  a S. Pantaleone.
# 1450
# Pedrocchi (Calle)  a S. Moisè.
# 1650
# Piasentini (Calle)  a S. Giovanni Nuovo.
# 1450
# Piasentini (Calle)  a S. Giovanni Nuovo.
# 1550
# Pignate (Ponte delle)  a S. Luca, in «Calle dei Fabbri».
# 1750
# Piombo (Rio del)  a S. Marina.
# 1650
# Pizzochere (Corte delle)  all’Angelo Raffaele.
# 1751
# Pompea (Calle)  alla Carità.
# 1650
# Ruga Giuffa  (Fondamenta dietro, Ponte di)  a S. Maria Formosa.
# 1750
# Rezzonico (Fondamenta)  a S. Barnaba.
# 1850
# Rialto (Ponte, Sottoportici di).
# 950
# Richetti (Calle) a S. Maurizio.
# 1650
# Ridotto (Calle del)  a S. Moisè.
# 1450
# S. Alvise (Campo, Rio, Secchere).
# 1650
# S. Alvise (Campo, Rio, Secchere).
# 1750
# S. Andrea (Fondamenta, Rio, Ponte, Campo, Fondamenta di).
# 1750
# S. Antonino (Salizzada, Ponte, Rio, Campo).
# 750
# S. Aponal (Campo, Rio di).
# 1550
# S. Aponal (Campo, Rio di).
# 1650
# S. Bartolomeo (Merceria, Campo).
# 1550
# S. Bartolomeo (Merceria, Campo).
# 1532
# S. Boldo (Campo, Ponte).
# 1150
# S. Canciano (Parrocchia, Campo, Ponte, Rio, Rio Terrà).
# 1650
# S. Canciano (Parrocchia, Campo, Ponte, Rio, Rio Terrà).
# 1850
# S. Canciano (Parrocchia, Campo, Ponte, Rio, Rio Terrà).
# 1650
# S. Canciano (Parrocchia, Campo, Ponte, Rio, Rio Terrà).
# 1819
# S. Chiara (Fondamenta, Canale).
# 1650
# S. Daniele (Ponte, Rio, Campo, Ramo).
# 1550
# S. Fantino (Campo, Ponte).
# 1550
# S. Fantino (Campo, Ponte).
# 1650
# S. Felice (Parrocchia, Fondamenta, Rio, Campo, Traghetto, Ponte, Ramo e Ponte, Ponte Nuovo).
# 1650
# S. Fosca (Campo, Ponte, Rio, Salizzada, Calle).
# 1050
# S. Fosca (Campo, Ponte, Rio, Salizzada, Calle).
# 1741
# S. Geremia (Parrocchia, Salizzada, Campo, Traghetto).
# 1150
# S. Giacomo dall’Orio (Parrocchia, Campo, Rio).
# 1050
# S. Giacomo dall’Orio (Parrocchia, Campo, Rio).
# 1650
# S. Gioachino (Calle, Ponte, Fondamenta, Ramo) a Castello .
# 1250
# S. Giobbe (Fondamenta, Campo, Ponte, Rio di).
# 1550
# S. Giovanni di Malta (Corte).
# 1650
# S. Giustina (Campo, Fondamenta, Rio, Ponte, Salizzada, Campiello).
# 750
# S. Giustina (Campo, Fondamenta, Rio, Ponte, Salizzada, Campiello).
# 1650
# S. Giustina (Campo, Fondamenta, Rio, Ponte, Salizzada, Campiello).
# 1750
# S. Giustina (Campo, Fondamenta, Rio, Ponte, Salizzada, Campiello).
# 1850
# S. Lio (Salizzada, Campo).
# 1650
# S. Lorenzo (Fondamenta, Ponte, Rio, Campo, Fondamenta, Ramo della Fondamenta).
# 1550
# S. Lorenzo (Fondamenta, Ponte, Rio, Campo, Fondamenta, Ramo della Fondamenta).
# 1650
# S. Luca (Campo, Ramo va in Campo, Salizzada, Rio).
# 1150
# S. Luca (Campo, Ramo va in Campo, Salizzada, Rio).
# 1650
# S. Luca (Campo, Ramo va in Campo, Salizzada, Rio).
# 1310
# S. Lucia (Fondamenta, Nuova Fondamenta della Dogana principale, Calle del Traghetto di).
# 1450
# S. Maria Nova (Campo).
# 1350
# S. Maria Nova (Campo).
# 1650
# S. Maria Zobenigo (Parrocchia, Campo, Rio, Traghetto di).
# 1550
# S. Marina (Campo, Rio).
# 1350
# S. Marziale (Campo, Ponte, Rio).
# 850
# S. Paternian (Calle, Ponte, Salizzada, Rio Terrà).
# 950
# S. Pietro (Parrocchia, Campo, Ponte di).
# 1350
# S. Pietro (Parrocchia, Campo, Ponte di).
# 1650
# S. Pròvolo (Salizzada, Ponte, Rio, Campiello, Campo, Calle).
# 1050
# S. Silvestro (Parrocchia, Campo, Rio Terrà, Fondamenta ora Rio T errà, Sottoportico, Traghetto).
# 1250
# S. Silvestro (Parrocchia, Campo, Rio Terrà, Fondamenta ora Rio T errà, Sottoportico, Traghetto).
# 1750
# S. Simeone Piccolo (Fondamenta, Campo).
# 950
# S. Simeone Piccolo (Fondamenta, Campo).
# 1650
# S. Sofia (Campo, Rio, Traghetto).
# 1850
# S. Stin (Campo, Ponte, Rio).
# 1050
# S. Stin (Campo, Ponte, Rio).
# 1150
# S. Teodoro (Salizzada)  a S. Salvatore.
# 1350
# S. Tèrnita (Campo, Ponte, Rio).
# 1150
# S. Tèrnita (Campo, Ponte, Rio).
# 1650
# S. Tèrnita (Campo, Ponte, Rio).
# 1850
# S. Tèrnita (Campo, Ponte, Rio).
# 1450
# S. Tèrnita (Campo, Ponte, Rio).
# 1650
# S. Tèrnita (Campo, Ponte, Rio).
# 1536
# S. Vidal (Campiello, Campo, Traghetto, Rio di).
# 1750
# S. Vidal (Campiello, Campo, Traghetto, Rio di).
# 1585
# S. Zaccaria (Parrocchia, Campo, Calle, Sottoportico).
# 750
# S. Zaccaria (Parrocchia, Campo, Calle, Sottoportico).
# 1750
# S. Zaccaria (Parrocchia, Campo, Calle, Sottoportico).
# 1850
# S. Zan Degol à (Fondamenta, Rio, Campo, Traghetto).
# 1150
# S. Zan Degol à (Fondamenta, Rio, Campo, Traghetto).
# 1350
# San Giovanni (Ruga Vecchia).
# 1550
# Scuola (Corte della)  a San Giovanni Evangelista.
# 750
# Scuola (Campiello dietro la)  a S. Fantino.
# 1750
# Scuola (Calle della)  allo Spirito Santo.
# 1748
# SS. Apostoli (Parrocc hia, Campo, Rio, Ponte, Sottoportico, Rio terrà).
# 750
# SS. Apostoli (Parrocc hia, Campo, Rio, Ponte, Sottoportico, Rio terrà).
# 1850
# SS. Filippo e Giacomo (Campo).
# 1450
# SS. Filippo e Giacomo (Campo).
# 1550
# Sabbionera (Sottoporti co e Corte)  alla Ca’ di Dio.
# 1550
# Saloni (Fondamenta ora Rio Terrà, Fondamenta e Ponte dei, Fondamenta delle Zattere alli)  a S. Gregorio.
# 1450
# Sansoni (Calle, Campiello dei)  a S. Apollinare.
# 1550
# Santi (Sottoportico dei)  a S. Gregorio.
# 1750
# Sanudo (Calle, Campiello) a  San Polo.
# 1350
# Sartorio (Fondamenta, Ponte)  a S. Basilio.
# 1750
# Scale (Calle, Sottoportico e Corte, Corte, Ramo e Corte delle) ai Frari.
# 1550
# Schiavine (Calle delle)  a S. Luca.
# 1450
# Schiavona (Calle)  a Castello, presso  S. Domenico.
# 1663
# Scoazzera (Campiello, Rio terrà della)  a S. Apollinare.
# 1550
# Scoazzera (Campiello, Rio terrà della)  a S. Apollinare.
# 1650
# Speron (Sottoportico, Corte)  in «Frezzeria».
# 1650
# Surian (Sottoportico, Calle)  al «Malcanton».
# 1550
# Testori (Calle dei)  a S. Andrea.
# 1450
# Tron (Calle, Rio)  a S. Eustachio.
# 1650
# Tabacco (Calle del)  o del Fig her all’«Anconetta».
# 1750
# Tagliapietra (Campiello del)  ai SS. Ermagora e Fortunato.
# 1652
# Tamossi (Fondamenta, Sottoportico, Calle, Ramo)  a S. Apollinare.
# 1650
# Terco (Calle del)  a Castello.
# 1750
# Terren (Campiello del)  a S. Nicolò.
# 1750
# Tole (Barbaria delle ) a SS. Giovanni e Paolo.
# 1750
# Torreselle (Rio delle)  a S. Vito.
# 1650
# Toscana (Calle , Ramo, Calle)  a Rialto.
# 1450
# Trevisana (Calle)  a S. Maria Formosa.
# 1550
# Turlona (Calle, Ponte)  a S. Girolamo.
# 1650
# Vallaresso (Calle) a S. Moisè.
# 1250
# Varisca (Calle, Ramo, Corte)  a S. Can ciano, in «Birri».
# 1550
# Veniera (Calle)  a S. Geremia.
# 1520
# Vergini (Calle delle)  a Castello.
# 1450
# Vergini (Calle delle)  a Castello.
# 1550
# Vergini (Calle delle)  a Castello.
# 1650
# Veriera (Sottoportico e Cort e) ai SS. Giovanni e Paolo.
# 1650
# Zane (Calle)  a S. Stin.
# 1350
# Zanetti (Corte)  a S. Maria Mater Domini.
# 1750
# Zoccolo (Corte, Ramo del)  a «Castello»,  in «Quintavalle».
# 1750
# Zotti (Calle, Ramo dei)  a S. Sam uele.
# 1683
# Zudìo (Calle del)  sulla «Fondamenta degli Ormesini».
# 1650
# Zulian (Sottoportico e Corte) a  S. Fosca.
# 1750

# %%
# transform into df
records = []
for place, years in place_year_dict.items():
    for year in years:
        records.append({'Place': place, 'Year': year})

df = pd.DataFrame(records)
df[df["Place"] == "Zusto (Salizzada, Ramo Salizzada)  a S. Giacomo dall’Orio."]
df.to_csv("../out/place_entity_df.csv", index=False)

# %%
import plotly.express as px

fig = px.scatter(df[df["Place"] == "Zusto (Salizzada, Ramo Salizzada)  a S. Giacomo dall’Orio."], x="Year", y="Place", title="Historical Mentions of Places",
                 labels={"Year": "Year", "Place": "Place"}, hover_data=['Place'])
fig.show()
