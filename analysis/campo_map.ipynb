# %%
import folium
import json
from branca.colormap import linear
import pandas as pd
from random import sample
import csv
import pyproj
import geopandas as gpd
import geojson
import numpy as np
from shapely.geometry import Point

# %%
with open("../out/geo_referencing_campo.json", "r", encoding='utf-8') as f:
    data = json.load(f)

# %%
first_numbers = [vals["years"][0] for vals in data.values() if vals["years"]]
min_val = min(first_numbers)
max_val = max(first_numbers)

colormap = linear.YlOrRd_09.scale(min_val, max_val)  # This one works in all common versions
colormap.caption = "First Number Scale"

# %%
# Create base map centered in Venice
venice_map = folium.Map(location=[45.4375, 12.3358], tiles="Cartodb Positron", zoom_start=14)

# Add markers
for name, info in data.items():
    if isinstance(info, dict) and info["years"] != []:
        first_number = info["years"][0]
        color = colormap(first_number)
        popup_text = f"<b>{name}</b><br><i>Year: {first_number}</i>"

        if "Campo" in name:
            folium.CircleMarker(
                location=[info["latitude"], info["longitude"]],
                radius=7,
                color=color,
                fill=True,
                fill_opacity=0.8,
                popup=popup_text,
                tooltip=name
            ).add_to(venice_map)
        else:
            folium.RegularPolygonMarker(
                location=[info["latitude"], info["longitude"]],
                radius=7,
                color=color,
                fill=True,
                fill_opacity=0.8,
                popup=popup_text,
                tooltip=name
            ).add_to(venice_map)
        
colormap.add_to(venice_map)

venice_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4825bb53882387a08d2c840033ed37aa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4825bb53882387a08d2c840033ed37aa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4825bb53882387a08d2c840033ed37aa = L.map(
#                 &quot;map_4825bb53882387a08d2c840033ed37aa&quot;,
#                 {
#                     center: [45.4375, 12.3358],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ff3eae874cf41a5f5b0f8aa35439f11c = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ff3eae874cf41a5f5b0f8aa35439f11c.addTo(map_4825bb53882387a08d2c840033ed37aa);
#
#
#             var circle_marker_494e6d131515d4d357a42980d4c08a4c = L.circleMarker(
#                 [45.4307785, 12.3342614],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffdb7aff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffdb7aff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4825bb53882387a08d2c840033ed37aa);
#
#
#         var popup_f4f5e864caf9f3a23ffcddf409184499 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d4d6066610a9299e6fd1f89e319cf90d = $(`&lt;div id=&quot;html_d4d6066610a9299e6fd1f89e319cf90d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Abazia (Fondamenta, Sottoportico, Campo, Ponte, Fondamenta dell’)  a S. Maria della Misericordia.&lt;/b&gt;&lt;br&gt;&lt;i&gt;Year: 939&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_f4f5e864caf9f3a23ffcddf409184499.setContent(html_d4d6066610a9299e6fd1f89e319cf90d);
#
#
#
#         circle_marker_494e6d131515d4d357a42980d4c08a4c.bindPopup(popup_f4f5e864caf9f3a23ffcddf409184499)
#         ;
#
#
#
#
#             circle_marker_494e6d131515d4d357a42980d4c08a4c.bindTooltip(
#                 `&lt;div&gt;
#                      Abazia (Fondamenta, Sottoportico, Campo, Ponte, Fondamenta dell’)  a S. Maria della Misericordia.
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_486c0e0a6ae278a7221747fbe63da2a7 = L.circleMarker(
#                 [45.431564, 12.3283317],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#feae4aff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#feae4aff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4825bb53882387a08d2c840033ed37aa);
#
#
#         var popup_f185bf731d57662a65cce20bc37e5f4f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0b1ed3dfb1d629e7ffb18384721dba1a = $(`&lt;div id=&quot;html_0b1ed3dfb1d629e7ffb18384721dba1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Carità (Rio terrà, Campo, Ponte della).&lt;/b&gt;&lt;br&gt;&lt;i&gt;Year: 1120&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_f185bf731d57662a65cce20bc37e5f4f.setContent(html_0b1ed3dfb1d629e7ffb18384721dba1a);
#
#
#
#         circle_marker_486c0e0a6ae278a7221747fbe63da2a7.bindPopup(popup_f185bf731d57662a65cce20bc37e5f4f)
#         ;
#
#
#
#
#             circle_marker_486c0e0a6ae278a7221747fbe63da2a7.bindTooltip(
#                 `&lt;div&gt;
#                      Carità (Rio terrà, Campo, Ponte della).
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_65bed6ae7ae494af0d38fc3c8cf7b3ac = L.circleMarker(
#                 [45.4377726, 12.3495249],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fe9b42ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fe9b42ff&quot;, &quot;fillOpacity&quot;: 0.8, &

# %%
geo_eval = pd.DataFrame(data)
geo_eval = sample(list(geo_eval.columns), 20)
geo_eval

with open('geo_reference_eval.csv', 'w') as f:
    
    write = csv.writer(f)
    
    write.writerow(["place", "true"])
    for row in geo_eval:
        write.writerow([row])

# %% [markdown]
# # test with streets geo data

# %%
with open("../out/test_geo_ref.json", "r", encoding='utf-8') as f:
    new_data = json.load(f)

# %%
first_numbers = [vals["years"][0] for vals in new_data.values() if vals["years"]]
min_val = min(first_numbers)
max_val = max(first_numbers)

colormap = linear.YlOrRd_09.scale(min_val, max_val)  # This one works in all common versions
colormap.caption = "First Mention"

# %%
def compute_centroid(coords):
    x_sum = sum(p[0] for p in coords)
    y_sum = sum(p[1] for p in coords)
    n = len(coords)
    return (x_sum / n, y_sum / n)

# %%
transformer = pyproj.Transformer.from_crs("epsg:32633", "epsg:4326", always_xy=True)

# %%
venice_map = folium.Map(location=[45.4375, 12.3358], tiles="Cartodb Positron", zoom_start=14)

# Add markers
for name, info in new_data.items():
    if isinstance(info, dict) and info["years"] != [] and name == "Calle della Scuola":
        first_number = info["years"][0]
        color = colormap(first_number)
        popup_text = f"<b>{name}</b><br><i>Year: {first_number}</i>"

        if info["location"] != {}:
            if info["location"]["type"] == "Polygon":
                coordinates = compute_centroid(info["location"]["coordinates"][0])
            elif info["location"]["type"] == "MultiPolygon":
                coordinates = compute_centroid(info["location"]["coordinates"][0][0])
            else:
                pass
            lon, lat = transformer.transform(*coordinates)  # UTM → lat/lon

            folium.CircleMarker(
                location=[lat, lon],
                radius=7,
                color=color,
                fill=True,
                fill_opacity=0.8,
                popup=popup_text,
                tooltip=name
            ).add_to(venice_map)

        
colormap.add_to(venice_map)

venice_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ca4d28d48567d0b229c34330d5a88a5f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ca4d28d48567d0b229c34330d5a88a5f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ca4d28d48567d0b229c34330d5a88a5f = L.map(
#                 &quot;map_ca4d28d48567d0b229c34330d5a88a5f&quot;,
#                 {
#                     center: [45.4375, 12.3358],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_42ca432ffc0886de361062f7f2543e7b = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_42ca432ffc0886de361062f7f2543e7b.addTo(map_ca4d28d48567d0b229c34330d5a88a5f);
#
#
#             var circle_marker_dbcb289c8bc65c5209c552c77b36adaf = L.circleMarker(
#                 [45.436523448430734, 12.337587504680997],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d5101fff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d5101fff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ca4d28d48567d0b229c34330d5a88a5f);
#
#
#         var popup_99e17fa475548bf424149fbd7a3dfbef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_917bcebbbf3f61bcd173797052c28f4b = $(`&lt;div id=&quot;html_917bcebbbf3f61bcd173797052c28f4b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Calle delle Acque&lt;/b&gt;&lt;br&gt;&lt;i&gt;Year: 1566&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_99e17fa475548bf424149fbd7a3dfbef.setContent(html_917bcebbbf3f61bcd173797052c28f4b);
#
#
#
#         circle_marker_dbcb289c8bc65c5209c552c77b36adaf.bindPopup(popup_99e17fa475548bf424149fbd7a3dfbef)
#         ;
#
#
#
#
#             circle_marker_dbcb289c8bc65c5209c552c77b36adaf.bindTooltip(
#                 `&lt;div&gt;
#                      Calle delle Acque
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_aa8f1bdb1cb7ef08c0abcf842031ee36 = L.circleMarker(
#                 [45.43625827812328, 12.325915021917716],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#eb2920ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#eb2920ff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ca4d28d48567d0b229c34330d5a88a5f);
#
#
#         var popup_d85018e129cda88fb6746ca15f57fce0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f4ee6b9bdba4660984a4e567c281d3c5 = $(`&lt;div id=&quot;html_f4ee6b9bdba4660984a4e567c281d3c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Calle degli Albanesi&lt;/b&gt;&lt;br&gt;&lt;i&gt;Year: 1443&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_d85018e129cda88fb6746ca15f57fce0.setContent(html_f4ee6b9bdba4660984a4e567c281d3c5);
#
#
#
#         circle_marker_aa8f1bdb1cb7ef08c0abcf842031ee36.bindPopup(popup_d85018e129cda88fb6746ca15f57fce0)
#         ;
#
#
#
#
#             circle_marker_aa8f1bdb1cb7ef08c0abcf842031ee36.bindTooltip(
#                 `&lt;div&gt;
#                      Calle degli Albanesi
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_6a0e80c54276b54ff725f2e24ec1960b = L.circleMarker(
#                 [45.44587512596723, 12.32882063558278],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fd532bff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fd532bff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ca4d28d48567d0b229c34330d5a88a5f);

# %% [markdown]
# # Compare within parishes

# %%
parishes_data = gpd.read_file("../1740_redrawn_parishes_cleaned_wikidata_standardised.geojson")

# %%
points_list = []


for key, info in new_data.items():
    if isinstance(info, dict) and info["years"] != []:
        if info["location"] != {}:
            if info["location"]["type"] == "Polygon":
                coordinates = compute_centroid(info["location"]["coordinates"][0])
            elif info["location"]["type"] == "MultiPolygon":
                coordinates = compute_centroid(info["location"]["coordinates"][0][0])
            else:
                pass
            lon, lat = transformer.transform(*coordinates)  # UTM → lat/lon

        points_list.append({'geometry': Point(lon, lat), 'first_year': info["years"][0]})

points_gdf = gpd.GeoDataFrame(points_list, crs=parishes_data.crs)

# %%
# Ensure both GeoDataFrames use the same CRS (coordinate reference system)
points_gdf = points_gdf.to_crs(parishes_data.crs)

# Spatial join: associate each point with the polygon it falls into
joined = gpd.sjoin(points_gdf, parishes_data, how='inner', predicate='within')

# Calculate average value per polygon
avg_values = joined.groupby('index_right')['first_year'].mean().round()
min_values = joined.groupby('index_right')['first_year'].min()

# Add avg_values back to polygons GeoDataFrame
parishes_data['avg_value'] = np.nan
parishes_data.loc[avg_values.index, 'avg_value'] = avg_values.values
parishes_data['min_value'] = np.nan
parishes_data.loc[min_values.index, 'min_value'] = min_values.values

# %%
min_val = parishes_data['avg_value'].min()
max_val = parishes_data['avg_value'].max()

colormap = linear.YlOrRd_09.scale(min_val, max_val)  # This one works in all common versions
colormap.caption = "First Number Scale"

# %%
# Create base map centered roughly on your data
m = folium.Map(location=[45.4375, 12.3358], tiles="Cartodb Positron", zoom_start=14)

def style_function(feature):
    val = feature['properties']['avg_value']
    if val is None or np.isnan(val):
        return {'fillColor': '#gray', 'color': 'black', 'weight': 1, 'fillOpacity': 0.5}
    else:
        return {'fillColor': colormap(val), 'color': 'black', 'weight': 1, 'fillOpacity': 0.7}
    
# Add polygons to map
folium.GeoJson(
    parishes_data,
    style_function=style_function,
    tooltip=folium.GeoJsonTooltip(fields=['NAME', 'avg_value'], aliases=['Name', 'Average Year']),
).add_to(m)

# Add color scale legend
colormap.caption = 'Average First Mention per Parish'
colormap.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2cc8cda83f8b51299205cd3f50203f7d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2cc8cda83f8b51299205cd3f50203f7d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2cc8cda83f8b51299205cd3f50203f7d = L.map(
#                 &quot;map_2cc8cda83f8b51299205cd3f50203f7d&quot;,
#                 {
#                     center: [45.4375, 12.3358],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_53e21268d78ddbb8a3b883a675853af0 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_53e21268d78ddbb8a3b883a675853af0.addTo(map_2cc8cda83f8b51299205cd3f50203f7d);
#
#
#         function geo_json_50a8e9e9c3b7376ca7a15169bf2c406d_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;62&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#gray&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#820026ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fea345ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;4&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd7936ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;5&quot;: case &quot;59&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d5101fff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;6&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ca0822ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feab49ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;8&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fe913dff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;10&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd572cff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;11&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ea271fff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;12&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#800026ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;13&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24cff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;14&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f13523ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;15&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd6831ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;16&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd6f33ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;17&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#e

# %%
min_val = parishes_data['min_value'].min()
max_val = parishes_data['min_value'].max()

colormap = linear.YlOrRd_09.scale(min_val, max_val)  # This one works in all common versions
colormap.caption = "First Number Scale"

# %%
# Create base map centered roughly on your data
m = folium.Map(location=[45.4375, 12.3358], tiles="Cartodb Positron", zoom_start=14)

def style_function(feature):
    val = feature['properties']['min_value']
    if val is None or np.isnan(val):
        return {'fillColor': '#gray', 'color': 'black', 'weight': 1, 'fillOpacity': 0.5}
    else:
        return {'fillColor': colormap(val), 'color': 'black', 'weight': 1, 'fillOpacity': 0.7}
    
# Add polygons to map
folium.GeoJson(
    parishes_data,
    style_function=style_function,
    tooltip=folium.GeoJsonTooltip(fields=['NAME', 'min_value'], aliases=['Name', 'First Mention']),
).add_to(m)

# Add color scale legend
colormap.caption = 'First Mention of Parish'
colormap.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_76e57e81cacf6fb26f12cd40c99d1b9b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_76e57e81cacf6fb26f12cd40c99d1b9b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_76e57e81cacf6fb26f12cd40c99d1b9b = L.map(
#                 &quot;map_76e57e81cacf6fb26f12cd40c99d1b9b&quot;,
#                 {
#                     center: [45.4375, 12.3358],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1d5e1d8334db0d3107591f4a01f0cbd0 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1d5e1d8334db0d3107591f4a01f0cbd0.addTo(map_76e57e81cacf6fb26f12cd40c99d1b9b);
#
#
#         function geo_json_2c4b501acd6cbe29fe24441d70008058_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;62&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#gray&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#800026ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fec35eff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;4&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#febe59ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;5&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd7c37ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;6&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fea144ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fffdc6ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;8&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd7033ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;10&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffe186ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;11&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f94728ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;12&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#820026ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;13&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb34dff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;14&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fffec9ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;15&quot;: case &quot;42&quot;: case &quot;45&quot;: case &quot;49&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffdb79ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;16&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#e2191cff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;17&quot;:
#                     return {&quot;color&quot;: &quot;bl
